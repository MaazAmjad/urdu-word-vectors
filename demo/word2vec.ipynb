# %%
# import modules & set up logging
from gensim.models import KeyedVectors

# %%
# Download the word2vec model.
# https://sgp1.digitaloceanspaces.com/urduhack/models/word-vectors/urdu_web_news_vector300_word2vec_linguistic_variation_1.bin

# %%
model = KeyedVectors.load_word2vec_format("/Users/ikram/WorkPlace/projects/urdu-ml/urduml/vectors/w2v/urdu_web_news_vector300_word2vec_linguistic_variation_1.bin",binary=True)

# %%
model.most_similar("پاکستان")
# Out:
# [('پاکستا', 0.7604117393493652),
#  ('کستان', 0.6326683163642883),
#  ('ْپاکستان', 0.5923380851745605),
#  ('ملک', 0.5424387454986572),
#  ('پاکسان', 0.5359625220298767),
#  ('پاکستانی', 0.525334894657135),
#  ('انڈیا', 0.5089199542999268),
#  ('اکستان', 0.5022765398025513),
#  ('پاسکتان', 0.49503034353256226),
#  ('پرپاکستان', 0.48905354738235474)]

# %%
model.most_similar(positive=['ملکہ', 'باپ'], negative=['بادشاہ'])
# Out:
# [('ماں', 0.5885621309280396),
#  ('شوہر', 0.5681419372558594),
#  ('خاوند', 0.5578209161758423),
#  ('بیٹی', 0.5434536337852478),
#  ('بیوی', 0.5390173196792603),
#  ('ساس', 0.5115535259246826),
#  ('بہو', 0.5104405879974365),
#  ('سسرال', 0.4926197826862335),
#  ('دادی', 0.49225014448165894),
#  ('بہن', 0.4832955002784729)]

# %%
model.most_similar(positive=['دلہن', 'شوہر'], negative=['دولہا'])
# Out:
# [('خاوند', 0.7515813112258911),
#  ('بیوی', 0.6855815649032593),
#  ('سسرالیوں', 0.6445579528808594),
#  ('بیٹی', 0.6375911235809326),
#  ('بہو', 0.6208239793777466),
#  ('سسرال', 0.6122082471847534),
#  ('ساس', 0.6103919744491577),
#  ('دیور', 0.6055386066436768),
#  ('اہلیہ', 0.6026074886322021),
#  ('منگیتر', 0.5898763537406921)]

# %%
model['پاکستان'].shape
# Out:
# (300,)

# %%
model['پاکستان']
# Out:
# array([-0.00426498, -0.03255285, -0.11142453,  0.14880398,  0.11596482,
#        -0.0377888 , -0.1006941 , -0.2842605 , -0.02402966, -0.04613459,
#         0.1181732 , -0.12518252, -0.12883207,  0.06312174,  0.12141722,
#         0.10182054,  0.0985846 ,  0.03490925,  0.62896675, -0.13760506,
#         0.02402611,  0.20848756, -0.06019154, -0.12996338,  0.17218474,
#        -0.1180554 ,  0.24187286,  0.07327607,  0.13535534, -0.25839016,
#        -0.05028214,  0.23064189,  0.3085766 ,  0.05881083,  0.05346143,
#         0.01118594, -0.2412527 ,  0.26436916, -0.19336872, -0.05221589,
#        -0.0393808 ,  0.21284407,  0.35765955,  0.10376871, -0.18897544,
#        -0.00831276,  0.04201808, -0.44043562, -0.14240727, -0.00351713,
#        -0.07310112,  0.2129036 ,  0.17070657, -0.06898511, -0.28615758,
#        -0.01087148, -0.0484148 , -0.1240915 ,  0.06894445,  0.09763666,
#        -0.01772524,  0.23377497, -0.03227402, -0.1230346 ,  0.00829425,
# ...
